# %%
import camelot

# %%
import pandas as pd

# %%
tables = camelot.read_pdf("Demographics_by_NTA.pdf", flavor="stream", pages="2-8")
tables
# Out:
# <TableList n=10>

# %%
tables[0].df
# Out:
#                                                  0         1      2        3   \
# 0
# 1
# 2                                                               Boro
# 3           Neighborhood Tabulation Area (NTA) Name  NTA Code         Boro CD
# 4                                                               Name
# 5
# 6
# 7
# 8                                Claremont-Bathgate      BX01  Bronx      203
# 9                   Eastchester-Edenwald-Baychester      BX03  Bronx      212
# 10                       Bedford Park-Fordham North      BX05  Bronx      207
# 11                                          Belmont      BX06  Bronx      206
# 12                                        Bronxdale      BX07  Bronx      211
# 13                           West Farms-Bronx River      BX08  Bronx      209
# 14  Soundview-Castle Hill-Clason Point-Harding Park      BX09  Bronx      209
# 15              Pelham Bay-Country Club-City Island      BX10  Bronx      210
# 16                                       Co-op City      BX13  Bronx      210
# 17                 East Concourse-Concourse Village      BX14  Bronx      204
# 18                                     East Tremont      BX17  Bronx      206
# 19              North Riverdale-Fieldston-Riverdale      BX22  Bronx      208
# 20                                       Highbridge      BX26  Bronx      204
# 21                                      Hunts Point      BX27  Bronx      202
# 22                            Van Cortlandt Village      BX28  Bronx      208
# 23                       Spuyten Duyvil-Kingsbridge      BX29  Bronx      208
# 24                              Kingsbridge Heights      BX30  Bronx      207
# 25                          Allerton-Pelham Gardens      BX31  Bronx      211
# 26                                         Longwood      BX33  Bronx      202
# 27                   Melrose South-Mott Haven North      BX34  Bronx      201
# 28                               Morrisania-Melrose      BX35  Bronx      203
# 29                University Heights-Morris Heights      BX36  Bronx      205
# 30          Van Nest-Morris Park-Westchester Square      BX37  Bronx      211
# 31                           Mott Haven-Port Morris      BX39  Bronx      201
# 32                                    Fordham South      BX40  Bronx      205
# 33                                       Mount Hope      BX41  Bronx      205
# 34                                          Norwood      BX43  Bronx      207
# 35                         Williamsbridge-Olinville      BX44  Bronx      212
# 36                                      Parkchester      BX46  Bronx      209
# 37                                   Pelham Parkway      BX49  Bronx      211
# 38         Schuylerville-Throgs Neck-Edgewater Park      BX52  Bronx      210
# 39                               Soundview-Bruckner      BX55  Bronx      209
#
#            4                      5      6            7            8     9   \
# 0
# 1       Total
# 2              65+ Population in NTA         % 65+ Below
# 3   populatio
# 4                                     % 65+      poverty  % Hispanic/
# 5           n            # 65+ years
# 6                                                              Latino
# 7                              years
# 8      35,560                  2,692    7.6         42.1               60.6
# 9      37,887                  4,939     13         11.7               24.6
# 10     57,685                  4,993    8.7           30                 75
# 11     29,115                  2,197    7.5         28.9                 61
# 12     39,423                  4,780   12.1         23.2               54.9
# 13     36,014                  4,063   11.3         21.3               65.8
# 14     54,925                  8,065   14.7         19.9               60.4
# 15     26,877                  5,375     20         12.2               41.4
# 16     47,400                 11,354     24         15.2               28.3
# 17     64,850                  7,727   11.9         30.8               63.3
# 18     44,057                  5,195   11.8           37               68.8
# 19     27,551                  7,066   25.6          9.8               21.6
# 20     39,140                  3,309    8.5         40.6               64.3
# 21     26,196                  2,551    9.7         45.1               70.7
# 22     50,935                  6,333   12.4         23.6               69.7
# 23     31,295                  7,431   23.7            9               38.7
# 24     32,163                  3,888   12.1         34.9               75.7
# 25     31,993                  6,274   19.6         11.7               36.3
# 26     27,864                  2,536    9.1         42.8               69.9
# 27     42,882                  4,062    9.5         40.1               65.6
# 28     40,925                  3,621    8.8         31.8               58.3
# 29     56,293                  4,749    8.4         45.3               68.9
# 30     29,004                  3,344   11.5         14.2               51.5
# 31     54,163                  4,708    8.7         46.6               68.8
# 32     28,164                  1,853    6.6         43.8               71.6
# 33     53,198                  4,661    8.8         36.6                 69
# 34     42,227                  3,855    9.1         29.9               63.5
# 35     66,606                  8,250   12.4         16.9               26.4
# 36     30,372                  3,562   11.7         15.7               38.2
# 37     28,913                  4,211   14.6         13.1               43.4
# 38     46,810                  7,374   15.8         14.2               49.2
# 39     37,130                  4,105   11.1         25.8               63.9
#
#          10                     11    12       13       14
# 0                % Race/Ethnicity,
# 1
# 2            all Population in NTA
# 3
# 4                 % Black/ African
# 5   % White                               % Asian  % Other
# 6                         American
# 7
# 8         1                         37.3      0.1     1.0%
# 9       3.1                           66      4.2     2.2%
# 10      4.2                         15.6      3.8     1.5%
# 11     18.2                         16.3      2.1     2.4%
# 12     13.9                         26.1      2.9     2.2%
# 13      2.7                         26.6      2.8     2.1%
# 14      2.7                         34.1      1.3     1.5%
# 15     49.4                          4.3      3.7     1.1%
# 16      6.6                         59.2      2.3     3.6%
# 17      1.6                         31.2      1.4     2.6%
# 18      1.4                         28.3      0.7     0.9%
# 19     61.8                          8.9      5.1     2.6%
# 20      2.5                         32.1      0.5     0.7%
# 21      1.7                         26.5      0.4     0.7%
# 22        8                         16.1      3.7     2.6%
# 23     45.7                          8.2      4.9     2.5%
# 24      3.5                         15.6      2.3     2.9%
# 25       21                           31      9.8     1.8%
# 26      1.7                         25.7      1.5     1.1%
# 27      1.7                         30.4      0.6     1.7%
# 28      1.2                         38.2        1     1.4%
# 29      1.1                         27.8      1.5     0.6%
# 30     24.3                         11.8       10     2.5%
# 31      1.9                           28      0.4     0.9%
# 32      0.7                         25.3      0.4     1.9%
# 33      1.3                         26.4      1.4     1.8%
# 34      9.7                         13.5     10.7     2.5%
# 35      2.4                         68.3      1.3     1.6%
# 36        2                         40.3     16.2     3.3%
# 37     30.7                         13.9       10     1.9%
# 38     36.3                          9.6      3.4     1.5%
# 39        3                         21.5      8.7     2.9%

# %%
df = pd.concat([
    tables[0].df,
    tables[1].df,
    tables[2].df,
    tables[3].df,
    tables[4].df,
    tables[5].df,
    tables[6].df,
    tables[7].df,
    tables[8].df,
    tables[9].df
], ignore_index=True)
df
# Out:
#                                                     0         1            2   \
# 0
# 1
# 2                                                                        Boro
# 3              Neighborhood Tabulation Area (NTA) Name  NTA Code
# 4                                                                        Name
# ..                                                 ...       ...          ...
# 364
# 365                                      Arden Heights      SI48  Staten Isla
# 366                                        Great Kills      SI54  Staten Isla
# 367                    park-cemetery-etc-Staten Island      SI99  Staten Isla
# 368  Sources: American Community Survey (ACS) by Ne...
#
#           3          4                      5      6                7   \
# 0
# 1                 Total
# 2                        65+ Population in NTA             % 65+ Below
# 3    Boro CD  populatio
# 4                                               % 65+          poverty
# ..       ...        ...                    ...    ...              ...
# 364                                      years
# 365      503     26,982            3,990\n14.8    9.7  13.4\n77.5\n1.6
# 366      503     42,306            7,499\n17.7   10.7   9.4\n83.5\n0.9
# 367      595          -                      -
# 368
#
#               8        9    10                     11   12   13   14
# 0                                   % Race/Ethnicity,
# 1
# 2                               all Population in NTA
# 3
# 4    % Hispanic/                     % Black/ African
# ..           ...      ...  ...                    ...  ...  ...  ...
# 364                        NaN                    NaN  NaN  NaN  NaN
# 365          6.1     1.4%  NaN                    NaN  NaN  NaN  NaN
# 366          5.2     0.9%  NaN                    NaN  NaN  NaN  NaN
# 367               #DIV/0!  NaN                    NaN  NaN  NaN  NaN
# 368                        NaN                    NaN  NaN  NaN  NaN
#
# [369 rows x 15 columns]

# %%
#Change the columns
df = df.rename(columns={
    0: 'Neighborhood_Name',
    1: 'NTA_Code',
    2: 'Boro_Name',
    3: 'Boro_CD',
    4: 'Total_pop',
    5: 'Num_65_over',
    6: 'Per_65_over',
    7: 'Per_65_over_poverty',
    8: 'Per_Hispanic_Latino',
    9: 'Per_White',
    10: 'Per_Black',
    11: 'Per_Asian',
    12: 'Per_Other'
})
df = df[df['Neighborhood_Name'] != 'Neighborhood_Name']
df
# Out:
#                                      Neighborhood_Name  NTA_Code    Boro_Name  \
# 0
# 1
# 2                                                                        Boro
# 3              Neighborhood Tabulation Area (NTA) Name  NTA Code
# 4                                                                        Name
# ..                                                 ...       ...          ...
# 364
# 365                                      Arden Heights      SI48  Staten Isla
# 366                                        Great Kills      SI54  Staten Isla
# 367                    park-cemetery-etc-Staten Island      SI99  Staten Isla
# 368  Sources: American Community Survey (ACS) by Ne...
#
#      Boro_CD  Total_pop            Num_65_over Per_65_over  \
# 0
# 1                 Total
# 2                        65+ Population in NTA
# 3    Boro CD  populatio
# 4                                                    % 65+
# ..       ...        ...                    ...         ...
# 364                                      years
# 365      503     26,982            3,990\n14.8         9.7
# 366      503     42,306            7,499\n17.7        10.7
# 367      595          -                      -
# 368
#
#     Per_65_over_poverty Per_Hispanic_Latino Per_White Per_Black  \
# 0
# 1
# 2           % 65+ Below
# 3
# 4               poverty         % Hispanic/
# ..                  ...                 ...       ...       ...
# 364                                                         NaN
# 365     13.4\n77.5\n1.6                 6.1      1.4%       NaN
# 366      9.4\n83.5\n0.9                 5.2      0.9%       NaN
# 367                                           #DIV/0!       NaN
# 368                                                         NaN
#
#                  Per_Asian      ANNUAL   14
# 0        % Race/Ethnicity,
# 1
# 2    all Population in NTA
# 3
# 4         % Black/ African
# ..                     ...  ...    ...  ...
# 364                    NaN  NaN    NaN  NaN
# 365                    NaN  NaN    NaN  NaN
# 366                    NaN  NaN    NaN  NaN
# 367                    NaN  NaN    NaN  NaN
# 368                    NaN  NaN    NaN  NaN
#
# [369 rows x 15 columns]

# %%
#drop any rows that have unnecessary values in the rebounds columns
df = df[df.Total_pop != "Total"]

# %%
df = df[df.Boro_Name != "Boro"]

# %%
df = df[df.NTA_Code != "NTA Code"]

# %%
df = df[df.Boro_Name != "Name"]
df = df[df.Total_pop != "n"]
df = df[df.Num_65_over != "years"]

# %%
df = df[df.Per_Hispanic_Latino != "Latino"]
df = df[df.Per_Asian != "% Race/Ethnicity,"]

# %%
df
# Out:
#                                      Neighborhood_Name NTA_Code    Boro_Name  \
# 8                                   Claremont-Bathgate     BX01        Bronx
# 9                      Eastchester-Edenwald-Baychester     BX03        Bronx
# 10                          Bedford Park-Fordham North     BX05        Bronx
# 11                                             Belmont     BX06        Bronx
# 12                                           Bronxdale     BX07        Bronx
# ..                                                 ...      ...          ...
# 363
# 365                                      Arden Heights     SI48  Staten Isla
# 366                                        Great Kills     SI54  Staten Isla
# 367                    park-cemetery-etc-Staten Island     SI99  Staten Isla
# 368  Sources: American Community Survey (ACS) by Ne...
#
#     Boro_CD Total_pop  Num_65_over Per_65_over Per_65_over_poverty  \
# 8       203    35,560        2,692         7.6                42.1
# 9       212    37,887        4,939          13                11.7
# 10      207    57,685        4,993         8.7                  30
# 11      206    29,115        2,197         7.5                28.9
# 12      211    39,423        4,780        12.1                23.2
# ..      ...       ...          ...         ...                 ...
# 363                                     Latino            American
# 365     503    26,982  3,990\n14.8         9.7     13.4\n77.5\n1.6
# 366     503    42,306  7,499\n17.7        10.7      9.4\n83.5\n0.9
# 367     595         -            -
# 368
#
#     Per_Hispanic_Latino Per_White Per_Black Per_Asian       ANNUAL    14
# 8                            60.6         1            37.3    0.1  1.0%
# 9                            24.6       3.1              66    4.2  2.2%
# 10                             75       4.2            15.6    3.8  1.5%
# 11                             61      18.2            16.3    2.1  2.4%
# 12                           54.9      13.9            26.1    2.9  2.2%
# ..                  ...       ...       ...       ...   ...    ...   ...
# 363                                     NaN       NaN   NaN    NaN   NaN
# 365                 6.1      1.4%       NaN       NaN   NaN    NaN   NaN
# 366                 5.2      0.9%       NaN       NaN   NaN    NaN   NaN
# 367                       #DIV/0!       NaN       NaN   NaN    NaN   NaN
# 368                                     NaN       NaN   NaN    NaN   NaN
#
# [294 rows x 15 columns]

# %%
df.to_csv('Demographic.csv', index=False)
